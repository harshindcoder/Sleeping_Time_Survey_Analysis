# %% [markdown]
# # Sleep time analysis data cleaning

# %% [markdown]
# ## Load libraries

# %%
import numpy as np
import pandas as pd

# %%
data1 = pd.read_csv('data/sleep_analysis_data.csv')
data2 = pd.read_csv('data/sleep_analysis_2_data.csv')

# %%
data = pd.concat([data1,data2])
data
# Out:
#     Age             Gender meals/day physical illness  screen time  \
# 0    22               Male       two               no         2hrs
# 1    22             Female     three               no      3-4 hrs
# 2    23               Male     three               no      3-4 hrs
# 3    23             Female       two               no      1-2 hrs
# 4    22               Male     three               no  more than 5
# ..  ...                ...       ...              ...          ...
# 41   22               Male     three               no      3-4 hrs
# 42   21               Male       two               no  more than 5
# 43   24               Male     three               no  more than 5
# 44   25  Prefer not to say     three              yes  more than 5
# 45   23             Female     three               no  more than 5
#
#    bluelight filter sleep direction   exercise smoke/drink  \
# 0               yes            west  sometimes          no
# 1                no           south         no          no
# 2                no           south         no          no
# 3                no            east  sometimes          no
# 4               yes            east  sometimes         yes
# ..              ...             ...        ...         ...
# 41               no            east  sometimes          no
# 42               no            east  sometimes          no
# 43              yes            east  sometimes          no
# 44              yes            east        yes         yes
# 45              yes            east  sometimes          no
#
#                beverage  sleep time
# 0                   Tea      6.7575
# 1                Coffee      8.0000
# 2                   Tea      8.0000
# 3                Coffee      6.5000
# 4   Tea and Coffee both      6.0000
# ..                  ...         ...
# 41                  Tea      6.0000
# 42                  Tea      7.0000
# 43    none of the above      4.0000
# 44  Tea and Coffee both      8.0000
# 45                  Tea      8.0000
#
# [92 rows x 11 columns]

# %% [markdown]
# ## Checking for data type and null values

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 92 entries, 0 to 45
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               92 non-null     int64
#  1   Gender            92 non-null     object
#  2   meals/day         92 non-null     object
#  3   physical illness  92 non-null     object
#  4   screen time       92 non-null     object
#  5   bluelight filter  92 non-null     object
#  6   sleep direction   92 non-null     object
#  7   exercise          92 non-null     object
#  8   smoke/drink       92 non-null     object
#  9   beverage          92 non-null     object
#  10  sleep time        92 non-null     float64
# dtypes: float64(1), int64(1), object(9)
# memory usage: 8.6+ KB

# %% [markdown]
# Null values are not present in our dataset.

# %% [markdown]
# ## All the different values in each column

# %%
labels = list(data.columns)
def values_type(data,labels):
    for label in labels:
        print(label ,": ",data[label].unique())

# %%
values_type(data,labels)
# Out:
# Age :  [22 23 24 28 59 25 39 50 20 21]
# Gender :  ['Male' 'Female' 'Prefer not to say']
# meals/day :  ['two' 'three' 'four' 'more than 5' 'five' 'one']
# physical illness :  ['no' 'yes']
# screen time :  ['2hrs' '3-4 hrs' '1-2 hrs' 'more than 5' '2-3 hrs' '4-5 hrs' '0-1 hrs']
# bluelight filter :  ['yes' 'no']
# sleep direction :  ['west' 'south' 'east' 'north']
# exercise :  ['sometimes' 'no' 'yes']
# smoke/drink :  ['no' 'yes']
# beverage :  ['Tea' 'Coffee' 'Tea and Coffee both' 'none of the above']
# sleep time :  [6.7575 8.     6.5    6.     7.     1.5    5.     3.33   9.     4.    ]

# %% [markdown]
# ## Round sleep time value to 2 decimals

# %%
data['sleep time'] = data['sleep time'].round(2)

# %% [markdown]
# ## Adding dummy variables for categorical data

# %%
# Change Gender into dummy varables
columns = pd.get_dummies(data['Gender'])
data = pd.concat([data,columns],axis = 1)

# %%
# Change sleep direction into dummy varables
columns = pd.get_dummies(data['sleep direction'])
data = pd.concat([data,columns],axis = 1)

# %%
# Change exercise into dummy varables
columns = pd.get_dummies(data['exercise'])
data = pd.concat([data,columns],axis = 1)

# %%
# Change beverage into dummy varables
columns = pd.get_dummies(data['beverage'])
data = pd.concat([data,columns],axis = 1)

# %%
data['Tea'] = data['Tea'] | data['Tea and Coffee both']
data['Coffee'] = data['Coffee'] | data['Tea and Coffee both']

# %% [markdown]
# ## Change column type from string to numerical

# %% [markdown]
# As of Q3 2023, on average users aged 16 to 64 worldwide spent 6 hours and 40 minutes per day on screens across various devices. That equals to 46 hours and 40 minutes for average screen time per week among worldwide internet users.

# %%
data['smoke/drink'] = data['smoke/drink'].apply(lambda x : 1 if x=='yes' else 0)
data['bluelight filter'] = data['bluelight filter'].apply(lambda x : 1 if x=='yes' else 0)
data['physical illness'] = data['physical illness'].apply(lambda x : 1 if x=='yes' else 0)
data['screen time'] = data['screen time'].apply(lambda x: 
    2 if x == '2hrs' else
    3.5 if x == '3-4hrs' else
    1.5 if x == '1-2 hrs' else
    6.67 if x == 'more than 5' else
    2.5 if x == '2-3 hrs' else
    4.5 if x == '4-5 hrs' else 
    0.5
)
data['meals/day'] = data['meals/day'].apply(lambda x: 
    1 if x == 'one' else
    2 if x == 'two' else
    3 if x == 'three' else
    4 if x == 'four' else
    5 if x == 'five' else
    6
)

# %% [markdown]
# ## Drop the unnecessary columns

# %%
data.drop(labels=['Gender', 'sleep direction', 'exercise', 'beverage', 'Tea and Coffee both'], axis=1, inplace=True)

# %% [markdown]
# ## Rename the unnecessary columns

# %%
data.rename(columns={
    'Age' : 'age',
    'Male' : 'male',
    'Female' : 'female',
    'none of the above': 'no_beverage',
    'sometimes':'seldom_exercise',
    'yes' : 'frequent_exercise',
    'no' : 'no_exercise',
    'Prefer not to say' : 'other_gender',
    'Tea' : 'tea',
    'Coffee' : 'coffee',
    'physical illness' : 'physical_illness',
    'bluelight filter' : 'bluelight_filter',
    'sleep time' : 'sleep_time',
    'screen time' : 'screen_time'
}, inplace=True)

# %%
data
# Out:
#     age  meals/day  physical_illness  screen_time  bluelight_filter  \
# 0    22          2                 0         2.00                 1
# 1    22          3                 0         0.50                 0
# 2    23          3                 0         0.50                 0
# 3    23          2                 0         1.50                 0
# 4    22          3                 0         6.67                 1
# ..  ...        ...               ...          ...               ...
# 41   22          3                 0         0.50                 0
# 42   21          2                 0         6.67                 0
# 43   24          3                 0         6.67                 1
# 44   25          3                 1         6.67                 1
# 45   23          3                 0         6.67                 1
#
#     smoke/drink  sleep_time  female   male  other_gender   east  north  south  \
# 0             0        6.76   False   True         False  False  False  False
# 1             0        8.00    True  False         False  False  False   True
# 2             0        8.00   False   True         False  False  False   True
# 3             0        6.50    True  False         False   True  False  False
# 4             1        6.00   False   True         False   True  False  False
# ..          ...         ...     ...    ...           ...    ...    ...    ...
# 41            0        6.00   False   True         False   True  False  False
# 42            0        7.00   False   True         False   True  False  False
# 43            0        4.00   False   True         False   True  False  False
# 44            1        8.00   False  False          True   True  False  False
# 45            0        8.00    True  False         False   True  False  False
#
#      west  no_exercise  seldom_exercise  frequent_exercise  coffee    tea  \
# 0    True        False             True              False   False   True
# 1   False         True            False              False    True  False
# 2   False         True            False              False   False   True
# 3   False        False             True              False    True  False
# 4   False        False             True              False    True   True
# ..    ...          ...              ...                ...     ...    ...
# 41  False        False             True              False   False   True
# 42  False        False             True              False   False   True
# 43  False        False             True              False   False  False
# 44  False        False            False               True    True   True
# 45  False        False             True              False   False   True
#
#     no_beverage
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# ..          ...
# 41        False
# 42        False
# 43         True
# 44        False
# 45        False
#
# [92 rows x 20 columns]

# %% [markdown]
# ## Rearrange columns

# %%
data.columns
# Out:
# Index(['age', 'meals/day', 'physical_illness', 'screen_time',
#        'bluelight_filter', 'smoke/drink', 'sleep_time', 'female', 'male',
#        'other_gender', 'east', 'north', 'south', 'west', 'no_exercise',
#        'seldom_exercise', 'frequent_exercise', 'coffee', 'tea', 'no_beverage'],
#       dtype='object')

# %%
data = data[['age', 'meals/day', 'physical_illness', 'screen_time',
       'bluelight_filter', 'smoke/drink', 'female', 'male',
       'other_gender', 'east', 'north', 'south', 'west', 'no_exercise',
       'seldom_exercise', 'frequent_exercise', 'coffee', 'tea',
       'no_beverage', 'sleep_time']]
data
# Out:
#     age  meals/day  physical_illness  screen_time  bluelight_filter  \
# 0    22          2                 0         2.00                 1
# 1    22          3                 0         0.50                 0
# 2    23          3                 0         0.50                 0
# 3    23          2                 0         1.50                 0
# 4    22          3                 0         6.67                 1
# ..  ...        ...               ...          ...               ...
# 41   22          3                 0         0.50                 0
# 42   21          2                 0         6.67                 0
# 43   24          3                 0         6.67                 1
# 44   25          3                 1         6.67                 1
# 45   23          3                 0         6.67                 1
#
#     smoke/drink  female   male  other_gender   east  north  south   west  \
# 0             0   False   True         False  False  False  False   True
# 1             0    True  False         False  False  False   True  False
# 2             0   False   True         False  False  False   True  False
# 3             0    True  False         False   True  False  False  False
# 4             1   False   True         False   True  False  False  False
# ..          ...     ...    ...           ...    ...    ...    ...    ...
# 41            0   False   True         False   True  False  False  False
# 42            0   False   True         False   True  False  False  False
# 43            0   False   True         False   True  False  False  False
# 44            1   False  False          True   True  False  False  False
# 45            0    True  False         False   True  False  False  False
#
#     no_exercise  seldom_exercise  frequent_exercise  coffee    tea  \
# 0         False             True              False   False   True
# 1          True            False              False    True  False
# 2          True            False              False   False   True
# 3         False             True              False    True  False
# 4         False             True              False    True   True
# ..          ...              ...                ...     ...    ...
# 41        False             True              False   False   True
# 42        False             True              False   False   True
# 43        False             True              False   False  False
# 44        False            False               True    True   True
# 45        False             True              False   False   True
#
#     no_beverage  sleep_time
# 0         False        6.76
# 1         False        8.00
# 2         False        8.00
# 3         False        6.50
# 4         False        6.00
# ..          ...         ...
# 41        False        6.00
# 42        False        7.00
# 43         True        4.00
# 44        False        8.00
# 45        False        8.00
#
# [92 rows x 20 columns]

# %% [markdown]
# ## Save the data as csv file

# %%
data.to_csv('data/clean_data.csv',index = False)
print("Data cleaning successful")
# Out:
# Data cleaning successful
